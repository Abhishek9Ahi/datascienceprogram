# %%
import numpy as np 
import seaborn as sns 
import pandas as pd

# %%
ages = [23,24,32,45,12,43,67,45,32,56,32,120]

# %%
a = sns.histplot(ages,kde=True)
print(a)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# KDE = kernal density estimator
# if you write  kde = True it make bell curve ( iska matlab ki ek line khich jayegi poore graph par )

# %% [markdown]
# # IRIS IS A DATASET IT PROVIDE BY THE JUPYTER SYSTEM

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # HISTOGRAM OF SEPAL_LENGTH

# %%
a = sns.histplot(df["sepal_length"],kde=True)
print(a)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# NOT FOLLOW NORMAL DISTRIBUTION ANS GASSIAN DISTRIBUTION BASED ON THE DIAGRAM

# %% [markdown]
# # HISTOGRAM OF SEPAL_WIDTH

# %%
s_w_histo = sns.histplot(df["sepal_width"],kde = True)

print(s_w_histo)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# Based on diagram we can say it is a follow gassian distribution ans normal distribution

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # HISTOGRAM OF PETAL_LENGTH

# %%
p_l_histo = sns.histplot(df["petal_length"],kde=True)
print(p_l_histo)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ON THE BASIS OF THIS PLOT WE CAN SAY VERY EASILY IT NOT FOLLOW NORMAL DISTRIBUTION OR GAUSSIAN DISTIBUTION

# %% [markdown]
# # HISTOGRAM OF PETAL_WIDTH

# %%
p_w_histo = sns.histplot(df["petal_width"],kde=True)

print(p_w_histo)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# # HOW TO CREATE NORMAL DISTRIBUTION DATA

# %% [markdown]
# random.normal(loc=0.0, scale=1.0, size=None)
#
# Parameters:
# locfloat or array_like of floats
# Mean (“centre”) of the distribution.
#
# scalefloat or array_like of floats
# Standard deviation (spread or “width”) of the distribution. Must be non-negative.
#
# sizeint or tuple of ints, optional
# Output shape. If the given shape is, e.g., (m, n, k), then m * n * k samples are drawn. If size is None (default), a single value is returned if loc and scale are both scalars. Otherwise, np.broadcast(loc, scale).size samples are drawn.
#
# Returns:
# outndarray or scalar
# Drawn samples from the parameterized normal distribution.

# %%
s = np.random.normal(0.5,0.2,1000)
print(s)
# Out:
# [ 0.49343078  0.41378521  0.46433945  0.39010964  0.73043932  0.4894358
#   0.51434853  0.40458136  0.33595358  0.25466076  0.74052671  0.43566078
#   0.03849005  0.40531563  0.54238449  0.70012883  0.96304781  0.56144577
#   0.66688925  0.47176799  0.49175063  0.48616418  0.47794789  0.58823576
#   0.47229553  0.17522643  0.47994729  0.51062846  0.34296788  0.74545548
#   0.25544033  0.38351913  0.17803801  0.38695861  0.83772884  0.25095682
#   0.27349989  0.32750788  0.40076683  0.54869007  0.67148202  0.87077022
#   0.29101081  0.67407096  0.27605274  0.20279022  0.55959352  0.06828349
#   0.75056618  0.4454521   0.66990616  0.85238743  0.64579958  0.27618601
#   0.54102192  0.69774335  0.64827936  0.85619725  0.54582027  0.31558124
#   0.49340451  0.56957316  0.28311899  0.81239382  0.3345281   0.37158106
#   0.29289303  0.6564326   0.65205105  0.64775741  0.02238084  0.43772141
#   0.53982618  0.42785823  0.51767411  0.32100573  0.89765676  0.55965974
# ...

# %%
a = sns.histplot(s,kde=True)
print(a)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# # OTHER DISTRIBUTION

# %% [markdown]
# # LOG NORMAL DISTRIBUTION ANS POWER LAW DISTRIBUTION

# %%
mu,sigma = 3.,1. ## mean and standard deviation 

s = np.random.lognormal(mu,sigma,1000)
print(s)
# Out:
# [ 28.50789805  12.7807191   17.96007916  59.69833275   2.80003818
#   24.49431686  63.51438773   3.5954574    7.38460433  46.84660227
#  275.23944205  39.58985122  18.87782583  26.24938845  78.53527916
#   20.64528417   4.99247882  24.93658194   2.5209152   13.41577596
#    3.37224625  17.77663142  11.57228442  13.27720874   4.5495014
#    7.90380354 161.60950076  14.78731274  15.33740195  15.10390892
#   26.43411762  51.12810676  22.96122409  16.26275344   7.50499147
#   42.17484654  13.01890611  23.40577264  11.37654976  74.98243056
#    2.87514769  27.13285321   3.70524654  17.00963561  31.28998127
#   29.62742331  71.62874043  16.11943275  53.26103962  40.21759514
#    9.11598609   6.33948822  21.83924238  18.80135785  32.59487174
#    1.75384872  17.38126347  44.84695439  29.50388817   9.60477592
#    3.11161708  53.87018149  30.46641466  70.66458311   4.57094137
#   68.30527625   2.30060097  22.31910747  16.1550299   55.77797579
# ...

# %%
a = sns.histplot(s,kde=True)
print(a)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# if you want convert this distribution into gassian distribution so you can take log in your variable

# %% [markdown]
# # EXAMPLE

# %%
a = sns.histplot(np.log(s),kde=True)  ## method for take log 

print(a)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# # CHECK WHETHER DISTRIBUTION IS NORMAL AND GAUSSINA DISTRIBUTIION

# %%
## If you want to check wether feature is gaussian or normal distribution 

### Q-Q plot 

import matplotlib.pyplot as plt 
import scipy.stats as stat
import pylab


def plot_data(sample):
    plt.figure(figsize=(10,6))   ## method for make subplot 
    plt.subplot(1,2,1)
    
    sns.histplot(sample)
    plt.subplot(1,2,2)
    
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %% [markdown]
# # Python PyLab Module

# %% [markdown]
# PyLab is a procedural interface to the Matplotlib object-oriented plotting library.
# Matplotlib is the whole package; matplotlib.pyplot is a module in Matplotlib;
# and PyLab is a module that gets installed alongside Matplotlib.
#
# PyLab is a convenience module that bulk imports matplotlib.pyplot (for plotting) and
# NumPy (for Mathematics and working with arrays) in a single name space.
# Although many examples use PyLab, it is no longer recommended.

# %% [markdown]
# # scipy module

# %% [markdown]
# This module contains a large number of probability distributions, summary and frequency statistics,
# correlation functions and statistical tests, masked statistics, kernel density estimation,
# quasi-Monte Carlo functionality, and more.

# %%
## create a normal distributed data 

s = np.random.normal(0.5,0.2,1000)
plot_data(s)

# %%
## we can see distrubution of sepal_width  in graphical way it show Gassien distribution 

plot_data(df["sepal_width"])

# %% [markdown]
# # PERSON AND SPERMAN RANK CORALETION

# %%
## load dataset from jupyter 

df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
df.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_30932\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
## how to make pairplot in seaborn 

sns.pairplot(df)
